# %% [markdown]
# ## Model loading

# %%
from transformers import Wav2Vec2Processor, Wav2Vec2ForCTC

### important !!!!!!!           # cVoice13_tone_v2Mapping   cVoice13_2nd_withDiph
path = "/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/models/cVoice13_tone_v2Mapping"
processor = Wav2Vec2Processor.from_pretrained(path)
model = Wav2Vec2ForCTC.from_pretrained(path)

# %% [markdown]
# # 1) Load the datasets and Parameters Settings

# %%
from datasets import load_from_disk
import pandas as pd
import torch

data_path = "/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/datasets/latic_l2_v1"

## Initial settings of Tone type txt   ###  Importantant  STEP 1)
file_path = "/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/Mandarin_List_attr_ToneV2.txt"  #

# Load the attribute mapping file               ## Setting before proceed IMPORTANT!!!!!!!   STEP 2)
csv_file_path = "/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/Mandarin_Tone_attributes_V2.csv"  # Mandarin_Tone_attributes_V2.csv  IPA_dragonMapperV3.csv
attribute_mapping = pd.read_csv(csv_file_path)

#### !!!!! VERY IMPORTANT               STEP 3)
which_type = "tone_pinyin_actual"  # This is from the datasets itself !!!
which_sentence = "sentence_speaker_said"  # This is from the datasets itself !!!
suppose_sentence = "tone_pinyin_suppose"

### Chocie can be                   'tone'     or     'IPA'     STEP 4)
choice = "tone"

data = load_from_disk(data_path)
data = data["train"]
data = data.select(range(50, 100))
data
# Out:
# Dataset({
#     features: ['audio', 'sentence_speaker_said', 'sentence_supposed_said', 'transcript_IPA_actual', 'tone_pinyin_actual', 'tone_pinyin_suppose', 'transcript_IPA_suppose', 'transcript_IPAwithTone_actual', 'transcript_IPAwithTone_suppose'],
#     num_rows: 50
# })

# %% [markdown]
# ### 2) Function settings

# %%
import re


## Step 1
def load_attribute_list(file_path):
    try:
        with open(file_path) as f:
            list_att = f.read().splitlines()
            return list_att
    except FileNotFoundError:
        raise FileNotFoundError(f"The list of attribute file {file_path} is not found")


list_att = load_attribute_list(file_path)


## Step 2
def create_binary_groups(list_att):
    groups = []
    for att in list_att:
        binary_att = [f"p_{att}", f"n_{att}"]  # Each attribute could be +ve or -ve
        groups.append(binary_att)
    return groups


groups = create_binary_groups(list_att)


## Step 3
def get_att_group_indx_map(bTraining=True):
    # Get group ids dictionary
    group_ids = [sorted(processor.tokenizer.convert_tokens_to_ids(group)) for group in groups]
    if bTraining:
        group_ids = [dict([(x[1], x[0] + 1) for x in list(enumerate(g))]) for g in group_ids]
    else:
        group_ids = [dict([(x[0] + 1, x[1]) for x in list(enumerate(g))]) for g in group_ids]
    return group_ids


group_ids = get_att_group_indx_map(bTraining=False)


## Step 4) Decouple if needed
decouple_diph_file = "/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/Diphthongs_Mandarin.csv"
with open(decouple_diph_file, "r", encoding="utf-8") as f:
    diphthongs_to_monophthongs_map = dict([(x.split(",")[0], " ".join(x.split(",")[1:])) for x in f.read().splitlines()])


def decouple_diphthongs(batch):
    # Compile a regular expression pattern to match any diphthong in the map
    pattern = r"|".join(re.escape(diph) for diph in diphthongs_to_monophthongs_map.keys())

    def replace_diphthong(phoneme_string):
        return re.sub(pattern, lambda x: diphthongs_to_monophthongs_map[x.group(0)], phoneme_string).split()

    return [phoneme for phoneme_string in batch for phoneme in replace_diphthong(phoneme_string)]

# %% [markdown]
# ## 3) Parameters, mode, file pre settings

# %%
def transpose_matrix(matrix):
    # Transpose the list of lists
    transposed_matrix = list(zip(*matrix))
    return transposed_matrix


def print_vertical(matrix):
    # Print each row of the matrix in a vertical format
    for row in matrix:
        print(" | ".join(row))


# Assuming `data` is a list of dictionaries with audio and actual_sentence sentences
prediction = []  ## A ordered speech attribute mapping of predcitions !!!!!!!
actual_sentence = []  ## A actual_sentence for checking !!!!!!!!!!
supposed_sentence = []
for item in data:
    audio_array = item["audio"]["array"]  # Extract the audio array
    sampling_rate = item["audio"]["sampling_rate"]  # Extract the sampling rate

    # Process the audio
    inputs = processor(audio_array, sampling_rate=sampling_rate, return_tensors="pt", padding=True)

    # Run the model inference
    with torch.no_grad():
        logits = model(inputs.input_values).logits

    item_output = []  # Store pred_temps for the current item only
    for i in range(len(group_ids)):
        mask = torch.zeros(logits.size()[2], dtype=torch.bool)
        mask[0] = True
        mask[list(group_ids[i].values())] = True
        logits_g = logits[:, :, mask]
        pred_ids = torch.argmax(logits_g, dim=-1)
        pred_ids = pred_ids.cpu().apply_(lambda x: group_ids[i].get(x, x))

        # Decode predictions and clean up
        temp = processor.batch_decode(pred_ids, spaces_between_special_tokens=True)[0]
        temp = temp.replace("p_", "")  # Perform replace during the temp stage
        item_output.append(temp.split())  # Collect the prediction parts for the current item

    # Append the item's transposed predictions to the global output
    transposed_item_output = transpose_matrix(item_output)
    prediction.append(transposed_item_output)  # Keep accumulating all items’ predictions in output

    actual_sentence.append(item[which_type].split())
    supposed_sentence.append(item[suppose_sentence])

    # # Print actual_sentence and prediction
    # print("-" * 100)
    # print("Actual Sentence:", item[suppose_sentence])
    # print("Actual correct IPA phoneme/ tone:", item[which_type])
    # print("Model Prediction from what Speakers said:")
    # print_vertical(transposed_item_output)


if "tone" in which_type:
    actual_sentence = [[int(item) for item in sublist] for sublist in actual_sentence]

# Important
# is_decouple = True
# if (is_decouple):
#     actual_sentence = [decouple_diphthongs(item) for item in actual_sentence]

# %% [markdown]
# # Pronunication Feedback Early design

# %%
from Levenshtein import opcodes, editops, distance
from collections import defaultdict
from typing import List, Dict, Tuple


# This method is used to match the recognized attibute list with the csv_dataFrame
def attibute_matching(csv_dataFrame, recognized_attibute_list: List, choice: str):
    best_match = "NoMandarinAttributeDetected!"
    best_score = 0

    for i in range(len(csv_dataFrame)):

        # Scenario 1）
        temp_list = csv_dataFrame.iloc[i]
        temp_attribute = [attribute for attribute, expected in temp_list.items() if expected == 1]

        if set(recognized_attibute_list) == set(temp_attribute):
            return temp_list[choice], False  # FULLY matching

        # Scenario 2） Find the most similiar one
        # Get Jaccard Similarity
        intersection = len(set(recognized_attibute_list) & set(temp_attribute))
        union = len(set(recognized_attibute_list) | set(temp_attribute))
        similarity = intersection / union if union != 0 else 0

        if similarity > best_score:
            best_score = similarity
            best_match = temp_list[choice]

    return best_match, True


# Compute the TA,FA,TR,FR
# Three sentence are needed for computing TA,FA,TR,FR
def compute_metrics(prediction: List, actual: List, supposed: List) -> Tuple[List[str], List[str]]:
    pred = prediction.split()
    actual = actual.split()
    supposed = supposed.split()

    # Metrcis_result only Store For TA,FA,TR,FR
    metrics_result = []
    diagnosed_result = []

    for i in range(len(pred)):
        temp = ""

        # Compute Accpetance and Rejection for the three list comparsion
        temp0 = "A" if actual[i] == supposed[i] else "R"
        temp1 = "A" if pred[i] == supposed[i] else "R"

        # Final Compute the TA,FA,TR,FR
        temp += "T" if temp0 == temp1 else "F"
        temp += "A" if pred[i] == supposed[i] else "R"

        metrics_result.append(temp)

        diagonsed = "CD" if pred[i] == actual[i] else "WD"
        diagnosed_result.append(diagonsed)

    return metrics_result, diagnosed_result


def compute_metrics_percentage(metrics: List, diagnosed: List) -> Tuple[float, float, float, float, float, float]:
    total = len(metrics)
    TA = round(metrics.count("TA") / total, 2) * 100
    TR = round(metrics.count("TR") / total, 2) * 100
    FA = round(metrics.count("FA") / total, 2) * 100
    FR = round(metrics.count("FR") / total, 2) * 100
    CD = round(diagnosed.count("CD") / total, 2) * 100
    WD = round(diagnosed.count("WD") / total, 2) * 100

    return TA, TR, FA, FR, CD, WD


# This is for one-to-one matching only
def compute_error_type(prediction: List, supposed: List):
    pred_temp = prediction.split()
    supposed_temp = supposed.split()
    result = []

    for i in range(len(pred_temp)):
        if pred_temp[i] == supposed_temp[i]:
            result.append("ok")
            continue

        if pred_temp[i] == "Unknown":
            result.append("Not CN word")
            continue

        if len(pred_temp[i]) == len(supposed_temp[i]):
            result.append("Substitution")
        elif len(pred_temp[i]) > len(supposed_temp[i]):
            result.append("Insertion")
        else:
            result.append("Deletion")

    return result


# Only useful in IpaAndTone together
def detail_checking(reference, predicted):
    result = {"phoneme_errors": {}, "tone_errors": {}}

    if not reference or not predicted:
        return result

    pred_phoneme = predicted[:-1] if predicted and predicted[-1].isdigit() else predicted
    pred_tone = predicted[-1] if predicted and predicted[-1].isdigit() else None
    rec_phoneme = reference[:-1] if reference and reference[-1].isdigit() else reference
    rec_tone = reference[-1] if reference and reference[-1].isdigit() else None

    if pred_phoneme != rec_phoneme:
        result["phoneme_errors"][rec_phoneme] = result["phoneme_errors"].get(rec_phoneme, 0) + 1
    elif pred_tone != rec_tone:
        result["tone_errors"][rec_tone] = result["tone_errors"].get(rec_tone, 0) + 1

    return result


# This is for non-one-to-one matching
def compute_levenshtein_metrics(ref: List[str], pred: List[str]) -> Tuple[Dict, List[str]]:
    cm = defaultdict(lambda: defaultdict(int))
    ops = editops(ref, pred)

    # 每个 index insert，在前面插入时不能直接操作原始列表
    error_map = defaultdict(list)

    for op, ref_i, pred_i in ops:
        if op == "insert":
            msg = f"ins({pred_i}:'{pred[pred_i]}')"
            error_map[ref_i].append(msg)
            cm["insertions"][pred[pred_i]] += 1
        elif op == "delete":
            msg = f"del({ref_i}:'{ref[ref_i]}')"
            error_map[ref_i].append(msg)
            cm["deletions"][ref[ref_i]] += 1
        elif op == "replace":
            msg = f"sub({ref_i}:'{ref[ref_i]}' -> '{pred[pred_i]}')"
            error_map[ref_i].append(msg)
            cm["substitutions"][(ref[ref_i], pred[pred_i])] += 1

    # 构造 error_list：每个 token 按照 ref 的顺序走，如果某处有插入，也加进去
    error_list = []
    for i in range(len(ref)):
        if i in error_map:
            for msg in error_map[i]:
                if msg.startswith("ins"):
                    error_list.append(msg)
        if i in error_map and any(m.startswith("del") or m.startswith("sub") for m in error_map[i]):
            # 如果有 delete 或 substitution，优先取第一个非-insert的
            main_error = next(m for m in error_map[i] if not m.startswith("ins"))
            error_list.append(main_error)
        else:
            error_list.append("ok")

    # 补充末尾如果还有 insert 操作（例如插入到 ref 最末尾）
    if len(ref) in error_map:
        for msg in error_map[len(ref)]:
            if msg.startswith("ins"):
                error_list.append(msg)

    return cm, error_list


def pretty_print_leveshtein_errors(errors: List[str]):
    for error in errors:
        print(error)


def align_sentence(ref: List[str], target: List[str], errors: List[str]):
    # Align the reference and prediction with error tags
    aligned_ref = []
    aligned_target = []

    ref_index = 0
    index = 0  # Track position in reference

    for error in errors:
        if error.startswith("ins"):  # Insertion case
            aligned_ref.append("ins")  # Add the phoneme from reference
            ref_index += 1
            aligned_target.append("emp")

            if index + 1 == len(target):
                if errors[-1].startswith("del"):
                    pass
                else:
                    aligned_target.append(target[index])

            if index < len(target) and index + 1 != len(target):
                aligned_target.append(target[index])

        elif error.startswith("del"):  # Deletion case

            # Special case when Actual sentence second time to align with supposed
            if index < len(target):
                if target[index] == "emp":
                    aligned_ref.append("emp")
                else:
                    aligned_ref.append("del")  # Placeholder for deletion

            if index < len(target):
                aligned_target.append(target[index])

        else:
            aligned_ref.append(ref[ref_index])
            ref_index += 1

            if index < len(target):
                aligned_target.append(target[index])

        index += 1  # Move to the next reference element

    return " ".join(aligned_ref), " ".join(aligned_target)


def check_prediction(predicted_attributes, reference, choice, detailCheck: bool):
    # step 1) First check the choice of prediction
    if choice == "tone":
        name = "Phoneme_PinyinTon"
    elif choice == "IPA":
        name = "Phoneme_ipaDragon"
    elif choice == "IpaAndTone":
        name = "Phoneme_ipaDragon"
    else:
        return "wrong function input"

    # Then Filter the mapping for the current phoneme tone
    expected_attributes = attribute_mapping[attribute_mapping[name] == reference]
    ## Optional -> Show the refernce in Pinyin/tone
    # reference = expected_attributes[optional].iloc[0]

    expected_attributes = expected_attributes.iloc[0].iloc[3:]

    # Step 2) Run the checking
    expected_attributes = [attribute for attribute, expected in expected_attributes.items() if expected == 1]

    predicted_set = set(predicted_attributes)
    correct_set = set(expected_attributes)

    check = correct_set.issubset(predicted_set)
    wrong_list = list(correct_set - predicted_set)
    extra_list = list(predicted_set - correct_set)

    # Step 3) Convert the prediction into Phoneme/tone
    recognized_phoneme, is_similiar = attibute_matching(attribute_mapping, predicted_attributes, name)

    if check:
        print(f"✅ Correct Pronunciation!")
    else:
        print("❌ Wrong Pronunciation Detected!")

    print(f"Phoneme/Tone: {reference}")

    # Print the most similar pronunciation if available
    if is_similiar:
        print(f"Most Similar Pronunciation: {recognized_phoneme}\n")
    else:
        print(f"Recognized as: {recognized_phoneme}\n")

    # Step 4: Print detailed attribute analysis if requested
    if detailCheck and is_similiar:
        print("Details:")
        print(f"  - Missing Attributes: {', '.join(wrong_list) if wrong_list else 'None'}")
        print(f"  - Extra Attributes: {', '.join(extra_list) if extra_list else 'None'}")
        print(f"  - Your Pronunciation Attributes: {', '.join(predicted_attributes)}")
        print(f"  - Expected Attributes: {', '.join(expected_attributes)}\n")
        detail_checking(reference, recognized_phoneme)

    return recognized_phoneme, reference

# %%
# Initialize counters and storage for sentences
i = 0
result = {}

TA_list = []
FA_list = []
TR_list = []
FR_list = []
CD_list = []
WD_list = []

total_TA = 0  # True Accept
total_FA = 0  # False Accept
total_TR = 0  # True Reject
total_FR = 0  # False Reject
total_CD = 0  # Correct Detection
total_WD = 0  # Wrong Detection


print("=" * 20 + " The Evaluation stat now " + "=" * 20)
print("=" * 65 + "\n")
for sentence in prediction:
    actual = []
    pred = []
    metrics = []

    # Loop through each item list in the sentence
    for j, item_list in enumerate(sentence):
        # Filter out items containing 'n_' from predicted attributes
        predicted_attributes = [item for item in item_list if "n_" not in item]

        out, ref = check_prediction(predicted_attributes, actual_sentence[i][j], choice, False)

        # Append the results
        actual.append(str(ref))
        pred.append(str(out))

        # Stop if reached end of reference for this sentence
        if j >= len(actual_sentence[i]) - 1:
            break

    # Display results for the current sentence
    actual = " ".join(actual)
    pred = " ".join(pred)

    # Case 1) Not equal number of strings evaluations       Levenshtein
    if len(pred.split()) != len(supposed_sentence[i].split()):
        supposed = supposed_sentence[i].split()
        pred = pred.split()
        actual = actual.split()

        print("=" * 20 + " SUMMARY: Not one-to-one " + "=" * 20)
        print(f"Supposed ({len(supposed)}):                           {' '.join(supposed)}")
        print(f"Actual ({len(actual)}):                             {' '.join(actual)}")
        print(f"Model Predictions ({len(pred)}):                  {' '.join(pred)} \n")

        print("Now we will start non one-to-one metrics computation:")  ## !!!!!!!!!!!!!!!!!!!!!
        if len(pred) < len(supposed_sentence[i].split()):

            cm, errors = compute_levenshtein_metrics(supposed, pred)
            cm_2, errors_2 = compute_levenshtein_metrics(supposed, actual)

            aligned_pred, aligned_supposed = align_sentence(pred, supposed, errors)
            aligned_actual, temp = align_sentence(actual, supposed, errors_2)

            cm_3, errors_3 = compute_levenshtein_metrics(aligned_supposed.split(), aligned_actual.split())
            aligned_actual, temp = align_sentence(aligned_actual.split(), aligned_supposed.split(), errors_3)

            print(f"Supposed ({len(aligned_supposed.split())}):                       {aligned_supposed}")
            print(f"Aligned Actual ({len(aligned_actual.split())}):                 {(aligned_actual)}")
            print(f"Aligned Predictions ({len(aligned_pred.split())}):            {(aligned_pred)} \n")

            metrics, diagnosed = compute_metrics(aligned_pred, aligned_actual, aligned_supposed)
            TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)

        else:
            cm, errors = compute_levenshtein_metrics(supposed, actual)
            temp, aligned_supposed = align_sentence(actual, supposed, errors)

            print(f"Aligned Supposed ({len(aligned_supposed.split())}):                   {aligned_supposed}")
            print(f"Actual ({len(actual)}):                             {' '.join(actual)}")
            print(f"Model Predictions ({len(pred)}):                  {' '.join(pred)} \n")

            metrics, diagnosed = compute_metrics(" ".join(pred), " ".join(actual), aligned_supposed)
            TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)

    else:
        # Case 2) One-to-One matching evaluations
        metrics, diagnosed = compute_metrics(pred, actual, supposed_sentence[i])
        TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)
        errors = compute_error_type(pred, supposed_sentence[i])

        print("=" * 20 + " SUMMARY: one-to-one " + "=" * 20)
        print(f"Supposed:                           {supposed_sentence[i]}")
        print(f"Actual:                             {actual}")
        print(f"Model Predictions:                  {pred}")

    print(f"MDD metrics:                        {metrics}")
    print(f"Diagonsed result:                   {diagnosed}")
    print(f"MDD metrics percentage:             TA {TA:.2f}%,  TR {TR:.2f}%,  FA {FA:.2f}%,  FR {FR:.2f}%,  CD {CD:.2f}%,  WD {WD:.2f}%")
    print(f"MDD Error Types:                    {errors}")
    print("=" * 50 + "\n")

    total_TA += TA
    total_FA += FA
    total_TR += TR
    total_FR += FR
    total_CD += CD
    total_WD += WD

    TA_list.append(TA)
    FA_list.append(FA)
    TR_list.append(TR)
    FR_list.append(FR)
    CD_list.append(CD)
    WD_list.append(WD)

    i += 1
# Out:
# ==================== The Evaluation stat now ====================
# =================================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 1 4 3 2 2 0 1 2 3 4 0 2 4
# Actual:                             4 1 4 3 2 2 0 1 2 3 4 0 2 4
# Model Predictions:                  4 4 4 3 1 2 0 4 2 2 4 0 2 4
# MDD metrics:                        ['TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 71.00%,  TR 0.00%,  FA 0.00%,  FR 29.00%,  CD 71.00%,  WD 29.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Most Similar Pronunciation: NoMandarinAttributeDetected!
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           3 2 4 4 4 3 2 1 0
# Actual:                             3 2 4 4 4 3 2 1 0
# Model Predictions:                  3 3 4 4 4 3 3 1 NoMandarinAttributeDetected!
# MDD metrics:                        ['TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD']
# MDD metrics percentage:             TA 67.00%,  TR 0.00%,  FA 0.00%,  FR 33.00%,  CD 67.00%,  WD 33.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Insertion']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           3 4 4 1 1 1 4 2 2 1 3 4 0 3 3
# Actual:                             3 4 4 1 1 1 4 2 2 1 3 4 0 3 3
# Model Predictions:                  3 4 4 1 1 1 4 2 3 4 2 4 0 3 2
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'FR', 'TA', 'TA', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'WD', 'CD', 'CD', 'CD', 'WD']
# MDD metrics percentage:             TA 73.00%,  TR 0.00%,  FA 0.00%,  FR 27.00%,  CD 73.00%,  WD 27.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 2
#
# ==================== SUMMARY: Not one-to-one ====================
# Supposed (18):                           2 3 2 0 3 4 1 4 4 4 4 3 2 4 2 0 3 2
# Actual (17):                             2 3 2 0 3 4 1 4 4 4 4 3 2 4 2 0 3
# Model Predictions (17):                  2 2 2 3 4 4 3 4 4 2 3 2 1 2 2 3 2
#
# Now we will start non one-to-one metrics computation:
# Supposed (18):                       2 3 2 0 3 4 1 4 4 4 4 3 2 4 2 0 3 2
# Aligned Actual (18):                 2 3 2 0 3 4 1 4 4 4 4 3 2 4 2 0 3 del
# Aligned Predictions (18):            2 2 2 del 3 4 4 3 4 4 2 3 2 1 2 2 3 2
#
# MDD metrics:                        ['TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'FA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'WD']
# MDD metrics percentage:             TA 56.00%,  TR 0.00%,  FA 6.00%,  FR 39.00%,  CD 56.00%,  WD 44.00%
# MDD Error Types:                    ['ok', "sub(1:'3' -> '2')", 'ok', "del(3:'0')", 'ok', 'ok', "sub(6:'1' -> '4')", "sub(7:'4' -> '3')", 'ok', 'ok', "sub(10:'4' -> '2')", 'ok', 'ok', "sub(13:'4' -> '1')", 'ok', "sub(15:'0' -> '2')", 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 2 2 3 4 4 0 1 4 4 2 4 2 4 0 1 4
# Actual:                             4 2 2 3 4 4 0 1 4 4 2 4 2 4 0 1 4
# Model Predictions:                  4 2 2 3 4 4 4 1 3 4 1 4 2 3 0 1 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 76.00%,  TR 0.00%,  FA 0.00%,  FR 24.00%,  CD 76.00%,  WD 24.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 3 4 1 2 4 4 2 2 3 4 2 2 2 2 4 2 4
# Actual:                             1 3 4 1 2 4 4 2 2 3 4 2 2 2 2 4 2 4
# Model Predictions:                  4 2 4 1 2 1 2 2 3 3 2 2 2 3 3 1 1 4
# MDD metrics:                        ['FR', 'FR', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'FR', 'FR', 'FR', 'TA']
# Diagonsed result:                   ['WD', 'WD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'WD', 'WD', 'WD', 'CD']
# MDD metrics percentage:             TA 44.00%,  TR 0.00%,  FA 0.00%,  FR 56.00%,  CD 44.00%,  WD 56.00%
# MDD Error Types:                    ['Substitution', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 2 4 0 3 4
# Actual:                             4 4 2 4 0 3 4
# Model Predictions:                  4 4 2 2 0 3 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 86.00%,  TR 0.00%,  FA 0.00%,  FR 14.00%,  CD 86.00%,  WD 14.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 4 4 3 3 2 2 2 1 3 3 4 4 4 2 4 0
# Actual:                             1 4 4 3 3 2 2 2 1 3 3 4 4 4 2 4 0
# Model Predictions:                  1 4 1 4 3 2 2 3 4 3 3 4 2 4 4 4 0
# MDD metrics:                        ['TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD']
# MDD metrics percentage:             TA 65.00%,  TR 0.00%,  FA 0.00%,  FR 35.00%,  CD 65.00%,  WD 35.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 2 2 4 4 2 3 2 2 0
# Actual:                             4 2 2 4 4 2 3 2 2 0
# Model Predictions:                  1 2 3 4 1 2 2 2 3 0
# MDD metrics:                        ['FR', 'TA', 'FR', 'TA', 'FR', 'TA', 'FR', 'TA', 'FR', 'TA']
# Diagonsed result:                   ['WD', 'CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'CD']
# MDD metrics percentage:             TA 50.00%,  TR 0.00%,  FA 0.00%,  FR 50.00%,  CD 50.00%,  WD 50.00%
# MDD Error Types:                    ['Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 2 2 4 4 0 4 4 1 2 4 1 4 3 3 4 3 0
# Actual:                             4 2 2 4 4 0 4 4 1 4 2 1 4 3 3 4 3 0
# Model Predictions:                  4 2 4 4 1 3 4 4 4 1 3 1 4 3 3 1 2 4
# MDD metrics:                        ['TA', 'TA', 'FR', 'TA', 'FR', 'FR', 'TA', 'TA', 'FR', 'TR', 'TR', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 50.00%,  TR 11.00%,  FA 0.00%,  FR 39.00%,  CD 50.00%,  WD 50.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 3 2 3 4 4 0 4 3 2 4 4 4 0
# Actual:                             4 3 2 3 4 4 0 4 3 2 4 4 4 0
# Model Predictions:                  4 3 2 3 1 1 0 4 1 2 4 4 1 0
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'WD', 'CD']
# MDD metrics percentage:             TA 71.00%,  TR 0.00%,  FA 0.00%,  FR 29.00%,  CD 71.00%,  WD 29.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 1 4 3 4 0 4 4
# Actual:                             4 1 4 3 4 0 4 4
# Model Predictions:                  4 1 4 3 4 0 4 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 100.00%,  TR 0.00%,  FA 0.00%,  FR 0.00%,  CD 100.00%,  WD 0.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 2 4 4 2 3 4 4 1 4 4
# Actual:                             4 4 2 4 4 2 3 4 4 1 4 4
# Model Predictions:                  4 4 0 1 4 2 3 4 1 3 4 1
# MDD metrics:                        ['TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'WD']
# MDD metrics percentage:             TA 58.00%,  TR 0.00%,  FA 0.00%,  FR 42.00%,  CD 58.00%,  WD 42.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 0 2 4 4 2 1 3 4 3 2 4 4 2 2 0 4
# Actual:                             4 0 2 4 4 2 1 3 4 3 2 4 4 2 2 0 4
# Model Predictions:                  4 3 4 4 4 3 1 3 1 3 4 4 4 3 3 1 1
# MDD metrics:                        ['TA', 'FR', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 47.00%,  TR 0.00%,  FA 0.00%,  FR 53.00%,  CD 47.00%,  WD 53.00%
# MDD Error Types:                    ['ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 2 2 2 3 1 2 4 3 2 2 3
# Actual:                             1 2 2 2 3 1 2 4 2 2 2 3
# Model Predictions:                  1 2 2 2 3 1 2 4 3 2 2 3
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 92.00%,  TR 0.00%,  FA 8.00%,  FR 0.00%,  CD 92.00%,  WD 8.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 0 4 2 2 4 1 1 3 4 3 4 2 1 4 0 4 4
# Actual:                             4 0 4 2 2 4 1 1 3 4 3 4 2 1 4 0 4 4
# Model Predictions:                  4 4 4 4 2 4 4 1 1 3 4 3 1 4 1 1 0 4
# MDD metrics:                        ['TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'CD']
# MDD metrics percentage:             TA 33.00%,  TR 0.00%,  FA 0.00%,  FR 67.00%,  CD 33.00%,  WD 67.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: NoMandarinAttributeDetected!
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           3 4 3 2 4 2 4 0 4 2
# Actual:                             3 4 2 3 4 2 4 0 4 2
# Model Predictions:                  3 4 3 3 4 2 1 0 1 NoMandarinAttributeDetected!
# MDD metrics:                        ['TA', 'TA', 'FA', 'TR', 'TA', 'TA', 'FR', 'TA', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'WD']
# MDD metrics percentage:             TA 50.00%,  TR 10.00%,  FA 10.00%,  FR 30.00%,  CD 60.00%,  WD 40.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'Insertion']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           3 4 3 2 4 4 4 0 3 4
# Actual:                             3 4 3 2 4 4 4 0 1 4
# Model Predictions:                  3 4 3 3 1 4 4 3 0 1
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'FR', 'TR', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 50.00%,  TR 10.00%,  FA 0.00%,  FR 40.00%,  CD 50.00%,  WD 50.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 0 3 4 0 4 2
# Actual:                             4 0 1 4 0 4 2
# Model Predictions:                  4 4 1 3 0 1 2
# MDD metrics:                        ['TA', 'FR', 'TR', 'FR', 'TA', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'CD']
# MDD metrics percentage:             TA 43.00%,  TR 14.00%,  FA 0.00%,  FR 43.00%,  CD 57.00%,  WD 43.00%
# MDD Error Types:                    ['ok', 'Substitution', 'Substitution', 'Substitution', 'ok', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 3 4 1 2 4 1 4 1 1 1
# Actual:                             4 3 3 1 2 4 1 4 1 1 1
# Model Predictions:                  4 3 3 4 2 4 1 1 4 1 1
# MDD metrics:                        ['TA', 'TA', 'TR', 'FR', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD']
# MDD metrics percentage:             TA 64.00%,  TR 9.00%,  FA 0.00%,  FR 27.00%,  CD 73.00%,  WD 27.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           2 2 4 4 3
# Actual:                             2 2 4 4 3
# Model Predictions:                  2 3 1 1 3
# MDD metrics:                        ['TA', 'FR', 'FR', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'WD', 'WD', 'CD']
# MDD metrics percentage:             TA 40.00%,  TR 0.00%,  FA 0.00%,  FR 60.00%,  CD 40.00%,  WD 60.00%
# MDD Error Types:                    ['ok', 'Substitution', 'Substitution', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 3 0 1 4 2 3 4 4 1 3 1 1
# Actual:                             1 3 0 1 4 2 3 4 4 1 3 1 1
# Model Predictions:                  1 3 4 1 2 2 4 1 1 1 3 1 1
# MDD metrics:                        ['TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'FR', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 62.00%,  TR 0.00%,  FA 0.00%,  FR 38.00%,  CD 62.00%,  WD 38.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 2 4 1 2 3 3 4 0 1 4
# Actual:                             4 4 2 4 1 2 3 3 4 0 1 4
# Model Predictions:                  4 1 4 4 1 2 3 3 4 0 1 3
# MDD metrics:                        ['TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD']
# MDD metrics percentage:             TA 75.00%,  TR 0.00%,  FA 0.00%,  FR 25.00%,  CD 75.00%,  WD 25.00%
# MDD Error Types:                    ['ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 0 4 2 2 4 0 4 0 1 4
# Actual:                             4 0 4 2 2 4 0 4 0 1 4
# Model Predictions:                  4 4 4 2 3 4 0 4 0 1 4
# MDD metrics:                        ['TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 82.00%,  TR 0.00%,  FA 0.00%,  FR 18.00%,  CD 82.00%,  WD 18.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           2 2 1 1 1 3 3 0 2 1 1 3 1 4
# Actual:                             2 2 1 1 1 3 3 0 2 1 1 3 1 4
# Model Predictions:                  2 4 1 4 1 2 2 0 4 4 1 3 1 4
# MDD metrics:                        ['TA', 'FR', 'TA', 'FR', 'TA', 'FR', 'FR', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'WD', 'CD', 'WD', 'WD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 57.00%,  TR 0.00%,  FA 0.00%,  FR 43.00%,  CD 57.00%,  WD 43.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'Substitution', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           2 3 2 4 2 1 4 0 4 4
# Actual:                             2 0 2 4 2 4 4 0 4 4
# Model Predictions:                  2 4 4 4 2 3 4 0 4 4
# MDD metrics:                        ['TA', 'TR', 'FR', 'TA', 'TA', 'TR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 70.00%,  TR 20.00%,  FA 0.00%,  FR 10.00%,  CD 70.00%,  WD 30.00%
# MDD Error Types:                    ['ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 2 4 4 4 4 0 4 0 2 4 0 4
# Actual:                             4 4 2 4 4 4 4 0 4 0 2 4 0 4
# Model Predictions:                  4 4 2 4 4 4 4 0 4 4 3 4 0 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 86.00%,  TR 0.00%,  FA 0.00%,  FR 14.00%,  CD 86.00%,  WD 14.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 0 4 1 0 4 3 0 1 4 2 0 1 4
# Actual:                             4 4 0 4 1 0 4 3 0 1 4 2 0 1 4
# Model Predictions:                  4 4 0 4 1 3 4 4 0 1 1 2 0 1 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 80.00%,  TR 0.00%,  FA 0.00%,  FR 20.00%,  CD 80.00%,  WD 20.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 4
#
# ==================== SUMMARY: Not one-to-one ====================
# Supposed (14):                           2 2 1 3 1 4 0 1 4 2 4 4 1 4
# Actual (13):                             2 2 1 3 1 4 0 1 4 2 4 4 1
# Model Predictions (13):                  2 3 1 3 4 4 1 4 4 4 4 4 4
#
# Now we will start non one-to-one metrics computation:
# Supposed (14):                       2 2 1 3 1 4 0 1 4 2 4 4 1 4
# Aligned Actual (14):                 2 2 1 3 1 4 0 1 4 2 4 4 1 del
# Aligned Predictions (14):            2 3 1 3 4 4 del 1 4 4 4 4 4 4
#
# MDD metrics:                        ['TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'FA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'WD']
# MDD metrics percentage:             TA 57.00%,  TR 0.00%,  FA 7.00%,  FR 36.00%,  CD 57.00%,  WD 43.00%
# MDD Error Types:                    ['ok', "sub(1:'2' -> '3')", 'ok', 'ok', "sub(4:'1' -> '4')", 'ok', "del(6:'0')", 'ok', 'ok', "sub(9:'2' -> '4')", 'ok', 'ok', "sub(12:'1' -> '4')", 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 3
#
# ...
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 4 2 3 4 4 2 4 0 1 4
# Actual:                             1 4 1 3 4 4 3 4 0 1 4
# Model Predictions:                  1 4 1 3 4 4 3 4 0 1 4
# MDD metrics:                        ['TA', 'TA', 'TR', 'TA', 'TA', 'TA', 'TR', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 82.00%,  TR 18.00%,  FA 0.00%,  FR 0.00%,  CD 100.00%,  WD 0.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Most Similar Pronunciation: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 4
#
# ==================== SUMMARY: Not one-to-one ====================
# Supposed (15):                           3 2 4 1 4 1 3 4 4 4 4 4 2 4 3
# Actual (14):                             3 2 4 1 4 1 3 4 4 4 4 4 2 4
# Model Predictions (14):                  3 1 4 4 4 1 3 4 4 4 4 4 4 4
#
# Now we will start non one-to-one metrics computation:
# Supposed (15):                       3 2 4 1 4 1 3 4 4 4 4 4 2 4 3
# Aligned Actual (15):                 3 2 4 1 4 1 3 4 4 4 4 4 2 4 del
# Aligned Predictions (15):            3 1 4 4 4 1 3 4 4 4 4 4 4 4 del
#
# MDD metrics:                        ['TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TR']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD']
# MDD metrics percentage:             TA 73.00%,  TR 7.00%,  FA 0.00%,  FR 20.00%,  CD 80.00%,  WD 20.00%
# MDD Error Types:                    ['ok', "sub(1:'2' -> '1')", 'ok', "sub(3:'1' -> '4')", 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', "sub(12:'2' -> '4')", 'ok', "del(14:'3')"]
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 3 3 1 1 4 4 4 4 1 2
# Actual:                             4 3 3 1 1 4 4 4 4 1 2
# Model Predictions:                  4 3 3 4 1 4 4 4 4 1 2
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 91.00%,  TR 0.00%,  FA 0.00%,  FR 9.00%,  CD 91.00%,  WD 9.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 0 3 1 3 2 4 4 2 3 0 1 4
# Actual:                             1 0 3 1 3 2 4 4 2 3 0 1 4
# Model Predictions:                  1 0 3 4 2 3 4 4 3 4 0 1 4
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'FR', 'FR', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'WD', 'WD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 62.00%,  TR 0.00%,  FA 0.00%,  FR 38.00%,  CD 62.00%,  WD 38.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'Substitution', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           2 3 2 2 4 4 2 4 4 4 0
# Actual:                             2 3 2 2 4 4 2 4 4 4 0
# Model Predictions:                  2 3 2 4 4 1 2 4 3 4 0
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD']
# MDD metrics percentage:             TA 73.00%,  TR 0.00%,  FA 0.00%,  FR 27.00%,  CD 73.00%,  WD 27.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           2 3 3 1 4 3 3 4 0 4 3
# Actual:                             2 3 3 1 4 3 3 4 0 4 3
# Model Predictions:                  2 2 3 1 4 3 3 4 0 4 3
# MDD metrics:                        ['TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 91.00%,  TR 0.00%,  FA 0.00%,  FR 9.00%,  CD 91.00%,  WD 9.00%
# MDD Error Types:                    ['ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 2 3 0 4 3 4 0 3 4 4 0 1 4 1 4
# Actual:                             4 2 3 0 4 3 4 0 3 4 4 0 1 4 1 4
# Model Predictions:                  1 2 3 0 4 3 4 3 3 1 1 0 1 4 1 4
# MDD metrics:                        ['FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 75.00%,  TR 0.00%,  FA 0.00%,  FR 25.00%,  CD 75.00%,  WD 25.00%
# MDD Error Types:                    ['Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           1 2 2 4 4 2 4
# Actual:                             1 2 2 4 4 2 4
# Model Predictions:                  4 2 2 2 4 2 4
# MDD metrics:                        ['FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 71.00%,  TR 0.00%,  FA 0.00%,  FR 29.00%,  CD 71.00%,  WD 29.00%
# MDD Error Types:                    ['Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 2
# Most Similar Pronunciation: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 4 4 0 2 2 4 3 4 4 0 3 3 2 4 4 1 4 0
# Actual:                             4 4 4 0 2 2 4 3 4 4 0 3 3 2 4 4 1 4 0
# Model Predictions:                  4 4 1 4 2 1 4 3 1 1 0 2 2 2 4 4 1 1 0
# MDD metrics:                        ['TA', 'TA', 'FR', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'FR', 'TA', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'WD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'WD', 'CD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD']
# MDD metrics percentage:             TA 58.00%,  TR 0.00%,  FA 0.00%,  FR 42.00%,  CD 58.00%,  WD 42.00%
# MDD Error Types:                    ['ok', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok']
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 3
# Recognized as: 3
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 1
# Most Similar Pronunciation: 1
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 2
# Recognized as: 2
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 0
# Recognized as: 0
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Most Similar Pronunciation: 1
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 1
# Recognized as: 4
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: 4
# Recognized as: 4
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 3
# Recognized as: 2
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 4
# Recognized as: 3
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: 0
# Recognized as: 4
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           4 3 1 2 0 4 1 4 3 3 4 0
# Actual:                             4 3 1 2 0 4 1 4 3 3 4 0
# Model Predictions:                  1 3 1 2 0 1 4 4 2 2 3 4
# MDD metrics:                        ['FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'FR', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'WD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 42.00%,  TR 0.00%,  FA 0.00%,  FR 58.00%,  CD 42.00%,  WD 58.00%
# MDD Error Types:                    ['Substitution', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'Substitution', 'Substitution', 'Substitution', 'Substitution']
# ==================================================

# %%
# Print the total calculations
num_sentences = i
avg_TA = total_TA / num_sentences
avg_FA = total_FA / num_sentences
avg_TR = total_TR / num_sentences
avg_FR = total_FR / num_sentences
avg_CD = total_CD / num_sentences
avg_WD = total_WD / num_sentences

# Compute the rates
FAR = total_FA / (total_FA + total_TR) if (total_FA + total_TR) > 0 else 0
# a rate that accept wrong answer

FRR = total_FR / (total_FR + total_TA) if (total_FR + total_TA) > 0 else 0
# a rate that reject correct answer

DER = total_WD / (total_CD + total_WD) if (total_CD + total_WD) > 0 else 0
# a rate that detect wrong answer

# Print results
print("=" * 30 + " PERFORMANCE METRICS " + "=" * 30)
print(f"False Acceptance Rate (FAR): {FAR:.4f}")
print(f"False Rejection Rate (FRR): {FRR:.4f}")
print(f"Diagnostic Error Rate (DER): {DER:.4f}")
print("=" * 80 + "\n")

## Final Confusion Amtrix
print("=" * 30 + " FINAL CONFUSION MATRIX " + "=" * 30)
print(f"Total Sentences Evaluated: {num_sentences}")
print(f"Total MDD Metrics:   TA {total_TA}, TR {total_TR}, FA {total_FA}, FR {total_FR}, CD {total_CD}, WD {total_WD}")
print(f"Average MDD %:       TA {avg_TA:.2f}%, TR {avg_TR:.2f}%, FA {avg_FA:.2f}%, FR {avg_FR:.2f}%, CD {avg_CD:.2f}%, WD {avg_WD:.2f}%")
print("=" * 80 + "\n")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

total_TA = int(total_TA)
total_FA = int(total_FA)
total_TR = int(total_TR)
total_FR = int(total_FR)

conf_matrix = np.array([[total_TA, total_FA], [total_FR, total_TR]])  # TA (True Accept), FA (False Accept)  # FR (False Reject), TR (True Reject)

labels = ["Accept", "Reject"]

plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)

plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - Tone Only Model")
plt.show()
# Out:
# ============================== PERFORMANCE METRICS ==============================
# False Acceptance Rate (FAR): 0.2549
# False Rejection Rate (FRR): 0.3304
# Diagnostic Error Rate (DER): 0.3362
# ================================================================================
#
# ============================== FINAL CONFUSION MATRIX ==============================
# Total Sentences Evaluated: 50
# Total MDD Metrics:   TA 3245, TR 114, FA 39, FR 1601, CD 3319.0, WD 1681.0
# Average MDD %:       TA 64.90%, TR 2.28%, FA 0.78%, FR 32.02%, CD 66.38%, WD 33.62%
# ================================================================================

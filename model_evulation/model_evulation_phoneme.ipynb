# %% [markdown]
# ## Model loading

# %%
from transformers import Wav2Vec2Processor,Wav2Vec2ForCTC
### important !!!!!!!           # cVoice13_tone_v2Mapping   cVoice13_2nd_withDiph 
path = '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/models/cVoice13_2nd_withDiph'
processor = Wav2Vec2Processor.from_pretrained(path)
model = Wav2Vec2ForCTC.from_pretrained(path)

# %% [markdown]
# # 1) Load the datasets and Parameters Settings

# %%
from datasets import load_from_disk
import pandas as pd
import torch 

# '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/datasets/latic_l2_V4'  CommonVoice13_CN
data_path = '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/datasets/latic_l2_v1'

## Initial settings   ###  Importantant                         STEP 1)
file_path = '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/Mandarin_List_attr_withDiph.txt'   # 

# Load the attribute mapping file                               STEP 2)
csv_file_path = '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/IPA_dragonMapperV3.csv'    # Mandarin_Tone_attributes_V2.csv  IPA_dragonMapperV3.csv
attribute_mapping = pd.read_csv(csv_file_path)

#### !!!!! VERY IMPORTANT                                       STEP 3)
which_type = 'transcript_IPA_actual'            # This is from the datasets itself !!!
which_sentence = 'sentence_speaker_said'        # This is from the datasets itself !!!
suppose_sentence = 'transcript_IPA_suppose'

### Chocie can be                   'tone'     or     'IPA'     STEP 4)
choice = 'IPA' 

data = load_from_disk(data_path)
data = data['train']
data = data.select(range(50,100))
data
# Out:
# Dataset({
#     features: ['audio', 'sentence_speaker_said', 'sentence_supposed_said', 'transcript_IPA_actual', 'tone_pinyin_actual', 'tone_pinyin_suppose', 'transcript_IPA_suppose', 'transcript_IPAwithTone_actual', 'transcript_IPAwithTone_suppose'],
#     num_rows: 50
# })

# %% [markdown]
# ### 2) Function settings

# %%
import re
## Step 1
def load_attribute_list(file_path):
    try:
        with open(file_path) as f:
            list_att = f.read().splitlines()
            return list_att
    except FileNotFoundError:
        raise FileNotFoundError(f"The list of attribute file {file_path} is not found")
             
list_att = load_attribute_list(file_path)

## Step 2 
def create_binary_groups(list_att):
    groups = []
    for att in list_att:
        binary_att = [f'p_{att}', f'n_{att}']  # Each attribute could be +ve or -ve
        groups.append(binary_att)
    return groups

groups = create_binary_groups(list_att)

## Step 3
def get_att_group_indx_map(bTraining=True):
    #Get group ids dictionary
    group_ids = [sorted(processor.tokenizer.convert_tokens_to_ids(group)) for group in groups]
    if bTraining:
        group_ids = [dict([(x[1],x[0]+1) for x in list(enumerate(g))]) for g in group_ids]
    else:
        group_ids = [dict([(x[0]+1,x[1]) for x in list(enumerate(g))]) for g in group_ids]
    return group_ids

group_ids = get_att_group_indx_map(bTraining=False)


## Step 4) Decouple if needed
decouple_diph_file = '/Users/evanchan19/Desktop/Thesis_Research/Mostafa_Phono_model/speech_attribute/data/Diphthongs_Mandarin.csv'
with open(decouple_diph_file, 'r', encoding='utf-8') as f:
    diphthongs_to_monophthongs_map = dict([(x.split(',')[0], ' '.join(x.split(',')[1:])) for x in f.read().splitlines()])

def decouple_diphthongs(batch):
    # Compile a regular expression pattern to match any diphthong in the map
    pattern = r'|'.join(re.escape(diph) for diph in diphthongs_to_monophthongs_map.keys())
    
    def replace_diphthong(phoneme_string):
        return re.sub(pattern, lambda x: diphthongs_to_monophthongs_map[x.group(0)], phoneme_string).split()
    
    return [phoneme for phoneme_string in batch for phoneme in replace_diphthong(phoneme_string)]

# %% [markdown]
# ## 3) Parameters, mode, file pre settings

# %%
def transpose_matrix(matrix):
    # Transpose the list of lists
    transposed_matrix = list(zip(*matrix))
    return transposed_matrix

def print_vertical(matrix):
    # Print each row of the matrix in a vertical format
    for row in matrix:
        print(" | ".join(row)) 

# Assuming `data` is a list of dictionaries with audio and actual_sentence sentences
prediction = []                                         ## A ordered speech attribute mapping of predcitions !!!!!!!
actual_sentence = []                                      ## A actual_sentence for checking !!!!!!!!!!
supposed_sentence = []
for item in data:
    audio_array = item["audio"]["array"]  # Extract the audio array
    sampling_rate = item["audio"]["sampling_rate"]  # Extract the sampling rate

    # Process the audio
    inputs = processor(audio_array, sampling_rate=sampling_rate, return_tensors="pt", padding=True)

    # Run the model inference
    with torch.no_grad():
        logits = model(inputs.input_values).logits

    item_output = []  # Store pred_temps for the current item only
    for i in range(len(group_ids)):
        mask = torch.zeros(logits.size()[2], dtype = torch.bool)
        mask[0] = True
        mask[list(group_ids[i].values())] = True
        logits_g = logits[:,:,mask]
        pred_ids = torch.argmax(logits_g,dim=-1)
        pred_ids = pred_ids.cpu().apply_(lambda x: group_ids[i].get(x,x))
        
        # Decode predictions and clean up
        temp = processor.batch_decode(pred_ids, spaces_between_special_tokens=True)[0]
        temp = temp.replace('p_', '')  # Perform replace during the temp stage
        item_output.append(temp.split())  # Collect the prediction parts for the current item

    # Append the item's transposed predictions to the global output
    transposed_item_output = transpose_matrix(item_output)
    prediction.append(transposed_item_output)  # Keep accumulating all items’ predictions in output
    
    actual_sentence.append(item[which_type].split())
    supposed_sentence.append(item[suppose_sentence])
    
    # # Print actual_sentence and prediction
    # print("-" * 100)
    # print("Actual Sentence:", item[suppose_sentence])
    # print("Actual correct IPA phoneme/ tone:", item[which_type])  
    # print("Model Prediction from what Speakers said:")
    # print_vertical(transposed_item_output)


if ('tone' in which_type):
    actual_sentence = [[int(item) for item in sublist] for sublist in actual_sentence]
    
# Important
# is_decouple = True
# if (is_decouple):
#     actual_sentence = [decouple_diphthongs(item) for item in actual_sentence]

# %% [markdown]
# # Pronunication Feedback Early design

# %%
from Levenshtein import opcodes, editops, distance
from collections import defaultdict
from typing import List, Dict, Tuple

# This method is used to match the recognized attibute list with the csv_dataFrame
def attibute_matching(csv_dataFrame, recognized_attibute_list: List, choice: str):
    best_match = 'NoMandarinAttributeDetected!'
    best_score = 0
    
    for i in range(len(csv_dataFrame)):
        
        # Scenario 1）
        temp_list = csv_dataFrame.iloc[i]
        temp_attribute = [attribute for attribute, expected in temp_list.items() if expected == 1]
        
        if set(recognized_attibute_list) == set(temp_attribute):
            return temp_list[choice], False  # FULLY matching
        
        # Scenario 2） Find the most similiar one
        # Get Jaccard Similarity
        intersection = len(set(recognized_attibute_list) & set(temp_attribute))
        union = len(set(recognized_attibute_list) | set(temp_attribute))
        similarity = intersection / union if union != 0 else 0
        
        if similarity > best_score:
            best_score = similarity
            best_match = temp_list[choice]
    
    return best_match, True

# Compute the TA,FA,TR,FR
# Three sentence are needed for computing TA,FA,TR,FR
def compute_metrics(prediction: List, actual: List, supposed: List) -> Tuple[List[str], List[str]]:
    pred = prediction.split()
    actual = actual.split()
    supposed = supposed.split()
    
    # Metrcis_result only Store For TA,FA,TR,FR
    metrics_result = []
    diagnosed_result = []
    
    for i in range(len(pred)):
        temp = ''

        # Compute Accpetance and Rejection for the three list comparsion
        temp0 = 'A' if actual[i] == supposed[i] else 'R'
        temp1 = 'A' if pred[i] == supposed[i] else 'R'

        # Final Compute the TA,FA,TR,FR
        temp += 'T' if temp0 == temp1 else 'F'
        temp += 'A' if pred[i] == supposed[i] else 'R'
        
        metrics_result.append(temp)
        
        diagonsed = 'CD' if pred[i] == actual[i] else 'WD'
        diagnosed_result.append(diagonsed)
           
    return metrics_result, diagnosed_result

def compute_metrics_percentage(metrics: List, diagnosed: List) -> Tuple[float, float, float, float, float, float]: 
    total = len(metrics)
    TA = round(metrics.count('TA') / total, 2) * 100
    TR = round(metrics.count('TR') / total, 2) * 100
    FA = round(metrics.count('FA') / total, 2) * 100
    FR = round(metrics.count('FR') / total, 2) * 100
    CD = round(diagnosed.count('CD') / total, 2) * 100
    WD = round(diagnosed.count('WD') / total, 2) * 100
    
    return TA,TR,FA,FR,CD,WD

# This is for one-to-one matching only
def compute_error_type(prediction: List, supposed: List):
    pred_temp = prediction.split()
    supposed_temp = supposed.split()
    result = []
    
    for i in range(len(pred_temp)):
        if (pred_temp[i] == supposed_temp[i]):
            result.append('ok')
            continue
        
        if (pred_temp[i] == 'Unknown'):
            result.append('Not CN word')
            continue
        
        if (len(pred_temp[i]) == len(supposed_temp[i])):
            result.append('Substitution')
        elif (len(pred_temp[i]) > len(supposed_temp[i])):
            result.append('Insertion')
        else:
            result.append('Deletion')
        
    return result

# Only useful in IpaAndTone together
def detail_checking(reference, predicted):
    result = {"phoneme_errors": {}, "tone_errors": {}}  


    if not reference or not predicted:
        return result

    pred_phoneme = predicted[:-1] if predicted and predicted[-1].isdigit() else predicted
    pred_tone = predicted[-1] if predicted and predicted[-1].isdigit() else None
    rec_phoneme = reference[:-1] if reference and reference[-1].isdigit() else reference
    rec_tone = reference[-1] if reference and reference[-1].isdigit() else None

    if pred_phoneme != rec_phoneme:
        result["phoneme_errors"][rec_phoneme] = result["phoneme_errors"].get(rec_phoneme, 0) + 1
    elif pred_tone != rec_tone:
        result["tone_errors"][rec_tone] = result["tone_errors"].get(rec_tone, 0) + 1

    return result

# This is for non-one-to-one matching
def compute_levenshtein_metrics(ref: List[str], pred: List[str]) -> Tuple[Dict, List[str]]:
    cm = defaultdict(lambda: defaultdict(int))
    ops = editops(ref, pred)

    # 每个 index insert，在前面插入时不能直接操作原始列表
    error_map = defaultdict(list)

    for op, ref_i, pred_i in ops:
        if op == 'insert':
            msg = f"ins({pred_i}:'{pred[pred_i]}')"  
            error_map[ref_i].append(msg)
            cm["insertions"][pred[pred_i]] += 1  
        elif op == 'delete':
            msg = f"del({ref_i}:'{ref[ref_i]}')"
            error_map[ref_i].append(msg)
            cm["deletions"][ref[ref_i]] += 1
        elif op == 'replace':
            msg = f"sub({ref_i}:'{ref[ref_i]}' -> '{pred[pred_i]}')"
            error_map[ref_i].append(msg)
            cm["substitutions"][(ref[ref_i], pred[pred_i])] += 1

    # 构造 error_list：每个 token 按照 ref 的顺序走，如果某处有插入，也加进去
    error_list = []
    for i in range(len(ref)):
        if i in error_map:
            for msg in error_map[i]:
                if msg.startswith("ins"):
                    error_list.append(msg)
        if i in error_map and any(m.startswith("del") or m.startswith("sub") for m in error_map[i]):
            # 如果有 delete 或 substitution，优先取第一个非-insert的
            main_error = next(m for m in error_map[i] if not m.startswith("ins"))
            error_list.append(main_error)
        else:
            error_list.append("ok")

    # 补充末尾如果还有 insert 操作（例如插入到 ref 最末尾）
    if len(ref) in error_map:
        for msg in error_map[len(ref)]:
            if msg.startswith("ins"):
                error_list.append(msg)

    return cm, error_list

def pretty_print_leveshtein_errors(errors: List[str]):
    for error in errors:
        print(error)

def align_sentence(ref: List[str], target: List[str], errors: List[str]):
   # Align the reference and prediction with error tags
    aligned_ref = []
    aligned_target = []
    
    ref_index = 0
    index = 0       # Track position in reference

    for error in errors:
        if error.startswith("ins"):     # Insertion case
            aligned_ref.append("ins")   # Add the phoneme from reference
            ref_index += 1
            aligned_target.append("emp")
            
            if (index + 1 == len(target)):
                if (errors[-1].startswith("del")):
                    pass
                else:
                    aligned_target.append(target[index])
                    
            if (index < len(target) and index + 1 != len(target)):
                aligned_target.append(target[index])
                
        elif error.startswith("del"):  # Deletion case
            
            # Special case when Actual sentence second time to align with supposed 
            if (index < len(target)):
                if (target[index] == 'emp'):
                    aligned_ref.append("emp")
                else:
                    aligned_ref.append("del")  # Placeholder for deletion
            
            if (index < len(target)):
                aligned_target.append(target[index])
                
        else:  
            aligned_ref.append(ref[ref_index])
            ref_index += 1
            
            if (index < len(target)):
                aligned_target.append(target[index])
            
        index += 1  # Move to the next reference element

    return ' '.join(aligned_ref), ' '.join(aligned_target)

def check_prediction(predicted_attributes, reference, choice, detailCheck: bool):
    # step 1) First check the choice of prediction
    if (choice == 'tone'):
        name = 'Phoneme_PinyinTon'
    elif (choice == 'IPA'):
        name = 'Phoneme_ipaDragon'
    elif (choice == 'IpaAndTone'):
        name = 'Phoneme_ipaDragon'
    else:
        return "wrong function input"
    
    # Then Filter the mapping for the current phoneme tone
    expected_attributes = attribute_mapping[attribute_mapping[name] == reference]
    ## Optional -> Show the refernce in Pinyin/tone
    # reference = expected_attributes[optional].iloc[0]
    
    expected_attributes = expected_attributes.iloc[0].iloc[3:]
    
    # Step 2) Run the checking
    expected_attributes = [attribute for attribute, expected in expected_attributes.items() if expected == 1]
    
    predicted_set = set(predicted_attributes)
    correct_set = set(expected_attributes)

    check = correct_set.issubset(predicted_set)
    wrong_list = list(correct_set - predicted_set)
    extra_list = list(predicted_set - correct_set)
    
    # Step 3) Convert the prediction into Phoneme/tone
    recognized_phoneme, is_similiar = attibute_matching(attribute_mapping, predicted_attributes, name)
    
    if check:
        print(f"✅ Correct Pronunciation!")
    else:
        print("❌ Wrong Pronunciation Detected!")

    print(f"Phoneme/Tone: {reference}")

    # Print the most similar pronunciation if available
    if is_similiar:
        print(f"Most Similar Pronunciation: {recognized_phoneme}\n")
    else:
        print(f"Recognized as: {recognized_phoneme}\n")

    # Step 4: Print detailed attribute analysis if requested
    if detailCheck and is_similiar:
        print("Details:")
        print(f"  - Missing Attributes: {', '.join(wrong_list) if wrong_list else 'None'}")
        print(f"  - Extra Attributes: {', '.join(extra_list) if extra_list else 'None'}")
        print(f"  - Your Pronunciation Attributes: {', '.join(predicted_attributes)}")
        print(f"  - Expected Attributes: {', '.join(expected_attributes)}\n")
        detail_checking(reference, recognized_phoneme)

    return recognized_phoneme, reference

# %%
# Initialize counters and storage for sentences
i = 0
result = {}

TA_list = []
FA_list = []
TR_list = []
FR_list = []
CD_list = []
WD_list = []

total_TA = 0  # True Accept
total_FA = 0  # False Accept
total_TR = 0  # True Reject
total_FR = 0  # False Reject
total_CD = 0  # Correct Detection
total_WD = 0  # Wrong Detection


print("="*20 + " The Evaluation stat now " + "="*20)
print("="*65 + "\n")
for sentence in prediction:
    actual = []
    pred = []
    metrics = []
    
    # Loop through each item list in the sentence
    for j, item_list in enumerate(sentence):
        # Filter out items containing 'n_' from predicted attributes
        predicted_attributes = [item for item in item_list if 'n_' not in item]
        
        out, ref = check_prediction(predicted_attributes, actual_sentence[i][j], choice, True)
        
        # Append the results
        actual.append(ref)
        pred.append(out)
        
        # Stop if reached end of reference for this sentence
        if j >= len(actual_sentence[i]) - 1:
            break
    
    # Display results for the current sentence
    actual = ' '.join(actual)
    pred = ' '.join(pred)
    
    # Case 1) Not equal number of strings evaluations       Levenshtein
    if len(pred.split()) != len(supposed_sentence[i].split()):
        supposed = supposed_sentence[i].split()
        pred = pred.split()
        actual = actual.split()
        
        print("="*20 + " SUMMARY: Not one-to-one " + "="*20)
        print(f"Supposed ({len(supposed)}):                           {' '.join(supposed)}")
        print(f"Actual ({len(actual)}):                             {' '.join(actual)}")
        print(f"Model Predictions ({len(pred)}):                  {' '.join(pred)} \n")
        
        print("Now we will start non one-to-one metrics computation:")                      ## !!!!!!!!!!!!!!!!!!!!!
        if (len(pred) < len(supposed_sentence[i].split())):
            
            cm, errors = compute_levenshtein_metrics(supposed, pred)
            cm_2, errors_2 = compute_levenshtein_metrics(supposed, actual)

            aligned_pred, aligned_supposed = align_sentence(pred, supposed, errors)
            aligned_actual, temp = align_sentence(actual, supposed, errors_2)

            cm_3, errors_3 = compute_levenshtein_metrics(aligned_supposed.split(), aligned_actual.split()) 
            aligned_actual, temp = align_sentence(aligned_actual.split(), aligned_supposed.split(), errors_3)
            
            print(f"Supposed ({len(aligned_supposed.split())}):                       {aligned_supposed}")
            print(f"Aligned Actual ({len(aligned_actual.split())}):                 {(aligned_actual)}")
            print(f"Aligned Predictions ({len(aligned_pred.split())}):            {(aligned_pred)} \n")
            
            metrics, diagnosed = compute_metrics(aligned_pred, aligned_actual, aligned_supposed)
            TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)
            
        else:  
            cm, errors = compute_levenshtein_metrics(supposed, actual)
            temp, aligned_supposed = align_sentence(actual, supposed, errors)
            
            print(f"Aligned Supposed ({len(aligned_supposed.split())}):                   {aligned_supposed}")
            print(f"Actual ({len(actual)}):                             {' '.join(actual)}")
            print(f"Model Predictions ({len(pred)}):                  {' '.join(pred)} \n")
            
            metrics, diagnosed = compute_metrics(' '.join(pred), ' '.join(actual), aligned_supposed)
            TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)
            
    else:
        # Case 2) One-to-One matching evaluations
        metrics, diagnosed = compute_metrics(pred, actual, supposed_sentence[i])
        TA, TR, FA, FR, CD, WD = compute_metrics_percentage(metrics, diagnosed)
        errors = compute_error_type(pred, supposed_sentence[i])
        
        print("="*20 + " SUMMARY: one-to-one " + "="*20)
        print(f"Supposed:                           {supposed_sentence[i]}")
        print(f"Actual:                             {actual}")
        print(f"Model Predictions:                  {pred}")
        
    print(f"MDD metrics:                        {metrics}")
    print(f"Diagonsed result:                   {diagnosed}")
    print(f"MDD metrics percentage:             TA {TA:.2f}%,  TR {TR:.2f}%,  FA {FA:.2f}%,  FR {FR:.2f}%,  CD {CD:.2f}%,  WD {WD:.2f}%")
    print(f"MDD Error Types:                    {errors}")
    print("="*50 + "\n")
    
    total_TA += TA
    total_FA += FA
    total_TR += TR
    total_FR += FR
    total_CD += CD
    total_WD += WD
    
    TA_list.append(TA)
    FA_list.append(FA)
    TR_list.append(TR)
    FR_list.append(FR)
    CD_list.append(CD)
    WD_list.append(WD)

    i += 1
# Out:
# ==================== The Evaluation stat now ====================
# =================================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɨ
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: kʰ
# Recognized as: kʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɕ
# Recognized as: tɕʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɥœ
# Recognized as: ɥœ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tsʰ
# Recognized as: tsʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: l
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɑʊ
# Recognized as: iɑʊ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           ʈʂ ɤ   t oʊ   ʂ ɨ   u   ʂ ɨ   n iɛ n   t ɤ   kʰ ɤ   ɕ ɥœ   ʂ ɨ   ʂ ɑ ŋ   t ɤ   tsʰ ai   l iɑʊ
# Actual:                             ʈʂ ɤ t oʊ ʂ ɨ u ʂ ɨ n iɛ n t ɤ kʰ ɤ ɕ ɥœ ʂ ɨ ʂ ɑ ŋ t ɤ tsʰ ai l iɑʊ
# Model Predictions:                  ʈʂ ɤ t oʊ ʂ ɨ u ʂ u n iɛ n t ɤ kʰ ɤ tɕʰ ɥœ ʂ ɨ ʂ ɑ ŋ t ɤ tsʰ ai t iɑʊ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD']
# MDD metrics percentage:             TA 90.00%,  TR 0.00%,  FA 0.00%,  FR 10.00%,  CD 90.00%,  WD 10.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wɔ
# Recognized as: wɔ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wɔ
# Recognized as: wɔ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           wɔ   p u   p i   ts ai   ʈʂ ɤ   l i   ɕ i ɑ ŋ   ʂ wɔ   l ɤ
# Actual:                             wɔ p u p i ts ai ʈʂ ɤ l i ɕ i ɑ ŋ ʂ wɔ l ɤ
# Model Predictions:                  wɔ p u p i ʈʂ ai ʈʂ ɤ l i ɕ i ɑ ŋ ʂ wɔ l ɤ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 95.00%,  TR 0.00%,  FA 0.00%,  FR 5.00%,  CD 95.00%,  WD 5.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wɔ
# Recognized as: wɔ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wɔ
# Recognized as: wɔ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tʰ
# Recognized as: tʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɥœ
# Recognized as: ɥœ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: s
# Recognized as: s
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɯ
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɕ
# Most Similar Pronunciation: ʈʂ
#
# Details:
#   - Missing Attributes: Fricative
#   - Extra Attributes: Affricate, Retroflex
#   - Your Pronunciation Attributes: Voiceless, Affricate, Retroflex, alveolopalatal
#   - Expected Attributes: Voiceless, Fricative, alveolopalatal
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           wɔ   ɕ iɛ n   ts ai   t a n   ʂ wɔ   tʰ a   ts ai   ʈʂ ɤ   ɕ ɥœ   s ɯ   ɕ i ɑ ŋ   ʂ ɑ ŋ   t ɤ   i ŋ   ɕ i ɑ ŋ
# Actual:                             wɔ ɕ iɛ n ts ai t a n ʂ wɔ tʰ a ts ai ʈʂ ɤ ɕ ɥœ s ɯ ɕ i ɑ ŋ ʂ ɑ ŋ t ɤ i ŋ ɕ i ɑ ŋ
# Model Predictions:                  wɔ ɕ iɛ n ʈʂ ai t a n ʂ wɔ tʰ a ʈʂ ai ʈʂ oʊ ɕ ɥœ s i ɕ i ɑ ŋ ʂ ɑ ŋ t ɤ i ŋ ʈʂ i ɑ ŋ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 86.00%,  TR 0.00%,  FA 0.00%,  FR 14.00%,  CD 86.00%,  WD 14.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: a
# Recognized as: ɑʊ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɑɻ
# Recognized as: ʐ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: w
# Recognized as: ɨ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ə
# Recognized as: w
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: ə
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: t
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: t
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʈʂ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: u
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: iɑʊ
# Recognized as: u
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: k
# Recognized as: iɑʊ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: wa
# Recognized as: k
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: wa
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: iɛ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: iɛ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʂ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɨ
# Recognized as: ʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: u
# Recognized as: ɨ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: l
# Recognized as: u
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ei
# Recognized as: l
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tɕʰ
# Recognized as: ei
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: i
# Recognized as: tɕʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: y
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɯ
# Recognized as: ts
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʐ
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: a
# Recognized as: l
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: a
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: t
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: t
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɕ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɥœ
# Recognized as: ɕ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: ɥœ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: ʈʂ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           t a   ɑɻ   w ə n   t ɤ   ʈʂ u   iɑʊ   k wa n   n iɛ n   ʂ ɨ   u   l ei   tɕʰ i   y   ts ɯ   ʐ a n   t ɤ   ɕ ɥœ n   ts ɤ
# Actual:                             t a ɑɻ w ə n t ɤ ʈʂ u iɑʊ k wa n n iɛ n ʂ ɨ u l ei tɕʰ i y ts ɯ ʐ a n t ɤ ɕ ɥœ n ts ɤ
# Model Predictions:                  t ɑʊ ʐ ɨ w ə n t ɤ ʈʂ u iɑʊ k wa n n iɛ n ʂ ɨ u l ei tɕʰ i i ts i l a n t ɤ ɕ ɥœ n ʈʂ
# MDD metrics:                        ['TA', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'TA', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'CD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 5.00%,  TR 0.00%,  FA 0.00%,  FR 95.00%,  CD 5.00%,  WD 95.00%
# MDD Error Types:                    ['ok', 'Insertion', 'Deletion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Deletion', 'Insertion', 'Deletion', 'Insertion', 'ok', 'Deletion', 'Insertion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Deletion', 'Insertion', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Deletion', 'Insertion']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ts
# Recognized as: ts
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɥœ
# Recognized as: ɥœ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʂ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wa
# Recognized as: wa
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: m
# Recognized as: m
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wa
# Recognized as: wa
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           ts ai   ʈʂ ɤ   ɕ ɥœ   ʂ ɨ   ʂ ɑ ŋ   ʈʂ ɤ   k ɤ   k wa n   n iɛ n   ʂ ɨ   i   k ɤ   k ɤ   m i ŋ   t ɤ   k wa n   n iɛ n
# Actual:                             ts ai ʈʂ ɤ ɕ ɥœ ʂ ɨ ʂ ɑ ŋ ʈʂ ɤ k ɤ k wa n n iɛ n ʂ ɨ i k ɤ k ɤ m i ŋ t ɤ k wa n n iɛ n
# Model Predictions:                  ts ai ʈʂ oʊ ɕ ɥœ ʂ ɨ ʈʂʰ ɑ ŋ ʈʂ ɤ k ɤ k wa n n iɛ n ʂ ɨ i k ɤ k ɤ m i ŋ t ɤ k wa n n iɛ n
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 95.00%,  TR 0.00%,  FA 0.00%,  FR 5.00%,  CD 95.00%,  WD 5.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: m
# Recognized as: m
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: tɕ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ai
# Recognized as: ia
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: kʰ
# Recognized as: kʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: wai
# Recognized as: wa
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           t a n   ʈʂ ɨ   n a   ʂ u   m i ŋ   u   l ei   y oʊ   l ai   p a   l ei   x ɤ   y oʊ   l ai   l iɛ n   ts ai   i   kʰ wai
# Actual:                             t a n ʈʂ ɨ n a ʂ u m i ŋ u l ei y oʊ l ai p a l ei x ɤ y oʊ l ai l iɛ n ts ai i kʰ wai
# Model Predictions:                  t a n ʈʂ ɨ n a ʂ u m i ŋ u l ei y oʊ l ai p a l ei x ɤ y oʊ l ai l iɛ n tɕ ia i kʰ wa
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD', 'WD']
# MDD metrics percentage:             TA 92.00%,  TR 0.00%,  FA 0.00%,  FR 8.00%,  CD 92.00%,  WD 8.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok', 'Deletion']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: m
# Recognized as: m
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɑʊ
# Recognized as: iɑʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           p iɛ n   ʂ ɨ   k ɤ   m i ŋ   t ɤ   p iɑʊ   ʂ ɨ
# Actual:                             k ɤ ŋ ʂ ɨ k ɤ m i ŋ t ɤ p iɑʊ ʂ ɨ
# Model Predictions:                  k ɤ ŋ ʂ ɨ k ɤ m i ŋ t ɤ p iɑʊ ʂ ɨ
# MDD metrics:                        ['TR', 'TR', 'TR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 81.00%,  TR 19.00%,  FA 0.00%,  FR 0.00%,  CD 100.00%,  WD 0.00%
# MDD Error Types:                    ['Substitution', 'Deletion', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ts
# Recognized as: ts
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɯ
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: u
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɥœ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ia
# Recognized as: ia
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʊ
# Recognized as: ʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           i n   w ei   ts ɯ   k u   i   l ai   ʈʂ ɤ   ɕ ɥœ   tɕ ia   ts ʊ ŋ   i   w ei   l ei   ʂ ɨ   p u   p iɛ n   t ɤ
# Actual:                             i n w ei ts ɯ k u i l ai ʈʂ ɤ ɕ ɥœ tɕ ia ts ʊ ŋ i w ei l ei ʂ ɨ p u p iɛ n t ɤ
# Model Predictions:                  i n w ei ts i k oʊ i l ai ʈʂ oʊ ɕ iɛ tɕ ia ʈʂ ʊ ŋ i w ei l ei ʂ ɨ p u p iɛ n t ɤ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 85.00%,  TR 0.00%,  FA 0.00%,  FR 15.00%,  CD 85.00%,  WD 15.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'Insertion', 'ok', 'Substitution', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂʰ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ioʊ
# Recognized as: ioʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: m
# Recognized as: m
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           i   ʈʂʰ ɤ ŋ   p u   p iɛ n   tɕ ioʊ   m ei   y oʊ   y oʊ   l ai   l ɤ
# Actual:                             i ʈʂʰ ɤ ŋ p u p iɛ n tɕ ioʊ m ei y oʊ y oʊ l ai l ɤ
# Model Predictions:                  i ʈʂʰ ɤ ŋ p u p iɛ n tɕ ioʊ m ei y oʊ y oʊ l ai l ɤ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 100.00%,  TR 0.00%,  FA 0.00%,  FR 0.00%,  CD 100.00%,  WD 0.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʐ
# Recognized as: ʐ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ts
# Recognized as: ts
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɯ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: f
# Recognized as: f
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ia
# Recognized as: ia
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ə
# Recognized as: ə
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ioʊ
# Recognized as: ioʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: m
# Recognized as: m
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʈʂʰ
# Recognized as: tsʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɨ
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           l i   ʐ u   i   l i   ɕ i ɑ ŋ   ts ɯ   tɕ iɛ n   tɕ iɛ n   ʂ ɤ ŋ   ia   f a   k ə n   p u   tɕ ioʊ   m a n   i   ʈʂʰ ɨ   l ɤ
# Actual:                             l i ʐ u i l i ɕ i ɑ ŋ ts ɯ tɕ iɛ n tɕ iɛ n ʂ ɤ ŋ f a ia k ə n p u tɕ ioʊ m a n i ʈʂʰ ɨ l ɤ
# Model Predictions:                  l i ʐ u i l i ɕ i ɑ ŋ ts ɤ tɕ iɛ n tɕ iɛ n ʂ ɤ ŋ f a ia k ə n p u tɕ ioʊ m a n i tsʰ i l ɤ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TR', 'TR', 'TR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'CD']
# MDD metrics percentage:             TA 85.00%,  TR 7.00%,  FA 0.00%,  FR 7.00%,  CD 93.00%,  WD 7.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Deletion', 'Substitution', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ioʊ
# Recognized as: ioʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂʰ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɕ
# Recognized as: tɕʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɑʊ
# Recognized as: iɑʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ioʊ
# Recognized as: ioʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂʰ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ==================== SUMMARY: Not one-to-one ====================
# Supposed (34):                           p u tɕ ioʊ ʈʂʰ ɤ ŋ ɕ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l ɤ
# Actual (33):                             p u tɕ ioʊ ʈʂʰ ɤ ŋ ɕ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l
# Model Predictions (33):                  p u tɕ ioʊ ʈʂʰ ɤ ŋ tɕʰ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l
#
# Now we will start non one-to-one metrics computation:
# Supposed (34):                       p u tɕ ioʊ ʈʂʰ ɤ ŋ ɕ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l ɤ
# Aligned Actual (34):                 p u tɕ ioʊ ʈʂʰ ɤ ŋ ɕ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l del
# Aligned Predictions (34):            p u tɕ ioʊ ʈʂʰ ɤ ŋ tɕʰ iɑʊ ɕ i ɑ ŋ ʂ u l ɤ p u tɕ ioʊ ʈʂʰ ɤ ŋ t a ɕ i ɑ ŋ ʂ u l del
#
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 94.00%,  TR 3.00%,  FA 0.00%,  FR 3.00%,  CD 97.00%,  WD 3.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', "sub(7:'ɕ' -> 'tɕʰ')", 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', "del(33:'ɤ')"]
# ==================================================
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʈʂ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Most Similar Pronunciation: ioʊ
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: backSound, diphthong
#   - Your Pronunciation Attributes: Unrounded, Back, Close-Mid, High-Mid, diphthong, backSound
#   - Expected Attributes: Unrounded, Back, Close-Mid, High-Mid
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: s
# Recognized as: s
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ə
# Recognized as: ə
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wa
# Recognized as: wa
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           ʈʂ ɤ   s w ei   ʂ ɨ   x ə n   t a   t ɤ   p iɛ n   x wa
# Actual:                             ʈʂ ɤ s w ei ʂ ɨ x ə n t a t ɤ p iɛ n x wa
# Model Predictions:                  tɕ ioʊ s w ei ʂ ɨ x ə n t a t ɤ p iɛ n x wa
# MDD metrics:                        ['FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 89.00%,  TR 0.00%,  FA 0.00%,  FR 11.00%,  CD 89.00%,  WD 11.00%
# MDD Error Types:                    ['Substitution', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tɕʰ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           t a n   p iɛ n   l ai   p iɛ n   tɕʰ y   x ai   ʈʂ ɨ   ʂ ɨ   i   ʈʂ u   ɕ i ɑ ŋ   ʂ u
# Actual:                             t a n p iɛ n l ai p iɛ n tɕʰ y x ai ʈʂ ɨ ʂ ɨ i ʈʂ u ɕ i ɑ ŋ ʂ u
# Model Predictions:                  t a n p iɛ n l ai p iɛ n tɕ y x ai ʈʂ ɨ ʂ ɨ i ʈʂ u ɕ i ɑ ŋ ʂ u
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 96.00%,  TR 0.00%,  FA 0.00%,  FR 4.00%,  CD 96.00%,  WD 4.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Deletion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɕ
# Recognized as: ɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ts
# Recognized as: ts
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɯ
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂʰ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ia
# Recognized as: ia
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɑʊ
# Recognized as: iɑʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂʰ
# Recognized as: ʈʂʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: pʰ
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: pʰ
# Recognized as: pʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           ɕ i ɑ ŋ   ts ɯ   p u   x w ei   p iɛ n   ʈʂʰ ɤ ŋ   ia   tɕ iɑʊ   ʂ u   iɛ   p u   x w ei   p iɛ n   ʈʂʰ ɤ ŋ   pʰ i   pʰ a   ʂ u
# Actual:                             ɕ i ɑ ŋ ts ɯ p u x w ei p iɛ n ʈʂʰ ɤ ŋ ia tɕ iɑʊ ʂ u iɛ p u x w ei p iɛ n ʈʂʰ ɤ ŋ pʰ i pʰ a ʂ u
# Model Predictions:                  ɕ i ɑ ŋ ts i p u x w ei p iɛ n ʈʂʰ ɤ ŋ ia tɕ iɑʊ ʂ u iɛ p u x w ei p iɛ n ʈʂʰ ɤ ŋ p i pʰ a ʂ u
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 95.00%,  TR 0.00%,  FA 0.00%,  FR 5.00%,  CD 95.00%,  WD 5.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Deletion', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕʰ
# Recognized as: tɕʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕʰ
# Recognized as: tɕʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʐ
# Recognized as: ʐ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tsʰ
# Recognized as: tsʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɯ
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕʰ
# Recognized as: tɕʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: iɛ
# Most Similar Pronunciation: iɛ
#
# Details:
#   - Missing Attributes: Low-Mid, Open-Mid, diphthong
#   - Extra Attributes: None
#   - Your Pronunciation Attributes: Unrounded, Front, midSound
#   - Expected Attributes: Unrounded, Front, Open-Mid, Low-Mid, diphthong, midSound
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʐ
# Recognized as: ʐ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tsʰ
# Recognized as: tsʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɯ
# Recognized as: i
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           tɕʰ iɛ n   n iɛ n   tɕʰ iɛ n   ʐ u   tsʰ ɯ   tɕʰ iɛ n   n iɛ n   x oʊ   iɛ   x ai   ʐ u   tsʰ ɯ
# Actual:                             tɕʰ iɛ n n iɛ n tɕʰ iɛ n ʐ u tsʰ ɯ tɕʰ iɛ n n iɛ n x oʊ iɛ x ai ʐ u tsʰ ɯ
# Model Predictions:                  tɕʰ iɛ n n iɛ n tɕʰ iɛ n ʐ u tsʰ i tɕʰ iɛ n n iɛ n x oʊ iɛ x ai ʐ u tsʰ i
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD']
# MDD metrics percentage:             TA 93.00%,  TR 0.00%,  FA 0.00%,  FR 7.00%,  CD 93.00%,  WD 7.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Most Similar Pronunciation: ʈʂ
#
# Details:
#   - Missing Attributes: None
# ...
#   - Extra Attributes: High-Mid, Close-Mid
#   - Your Pronunciation Attributes: Unaspirated, Voiceless, Plosive, Alveolar, Close-Mid, High-Mid
#   - Expected Attributes: Unaspirated, Voiceless, Plosive, Alveolar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Most Similar Pronunciation: ɨ
#
# Details:
#   - Missing Attributes: High-Mid, Close-Mid
#   - Extra Attributes: None
#   - Your Pronunciation Attributes: Unrounded, Back
#   - Expected Attributes: Unrounded, Back, Close-Mid, High-Mid
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tʰ
# Most Similar Pronunciation: tʰ
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: Front, diphthong
#   - Your Pronunciation Attributes: Aspirated, Voiceless, Plosive, Alveolar, Front, diphthong
#   - Expected Attributes: Aspirated, Voiceless, Plosive, Alveolar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: iɛ
# Most Similar Pronunciation: iɛ
#
# Details:
#   - Missing Attributes: Front, diphthong
#   - Extra Attributes: None
#   - Your Pronunciation Attributes: Unrounded, Open-Mid, Low-Mid, midSound
#   - Expected Attributes: Unrounded, Front, Open-Mid, Low-Mid, diphthong, midSound
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Most Similar Pronunciation: t
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: High-Mid, Close-Mid
#   - Your Pronunciation Attributes: Unaspirated, Voiceless, Plosive, Alveolar, Close-Mid, High-Mid
#   - Expected Attributes: Unaspirated, Voiceless, Plosive, Alveolar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: i
# Most Similar Pronunciation: ɨ
#
# Details:
#   - Missing Attributes: Close, Front, High
#   - Extra Attributes: Back
#   - Your Pronunciation Attributes: Unrounded, Back
#   - Expected Attributes: Unrounded, Front, Close, High
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Most Similar Pronunciation: k
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: diphthong
#   - Your Pronunciation Attributes: Unaspirated, Voiceless, Plosive, Velar, diphthong
#   - Expected Attributes: Unaspirated, Voiceless, Plosive, Velar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: wa
# Most Similar Pronunciation: wa
#
# Details:
#   - Missing Attributes: diphthong
#   - Extra Attributes: None
#   - Your Pronunciation Attributes: Rounded, Central, Open, Low, neutral, midSound
#   - Expected Attributes: Rounded, Central, Open, Low, neutral, diphthong, midSound
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Most Similar Pronunciation: n
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: Front, diphthong
#   - Your Pronunciation Attributes: Voiced, Nasal, Alveolar, Front, diphthong
#   - Expected Attributes: Voiced, Nasal, Alveolar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: iɛ
# Most Similar Pronunciation: iɛ
#
# Details:
#   - Missing Attributes: Front, diphthong
#   - Extra Attributes: None
#   - Your Pronunciation Attributes: Unrounded, Open-Mid, Low-Mid, midSound
#   - Expected Attributes: Unrounded, Front, Open-Mid, Low-Mid, diphthong, midSound
#
# ==================== SUMMARY: Not one-to-one ====================
# Supposed (37):                           ts w ei m i ŋ ɕ iɛ n t ɤ ʂ ɨ t a pʰ wɔ l ɤ y oʊ i ʈʂ ɨ t ɤ tʰ iɛ n t i k wa n n iɛ n
# Actual (36):                             ts w ei m i ŋ ɕ iɛ n t ɤ ʂ ɨ t a pʰ wɔ l ɤ y oʊ i ʈʂ ɨ t ɤ tʰ iɛ n t i k wa n n iɛ
# Model Predictions (36):                  tɕ y n m i ŋ ɕ iɛ n t ɨ ʂ ɨ t a pʰ wɔ l wɔ oʊ y i ʈʂ ɨ t ɨ tʰ iɛ n t ɨ k wa n n iɛ
#
# Now we will start non one-to-one metrics computation:
# Supposed (38):                       ts w ei m i ŋ ɕ iɛ n t ɤ ʂ ɨ t a pʰ wɔ l emp ɤ y oʊ i ʈʂ ɨ t ɤ tʰ iɛ n t i k wa n n iɛ n
# Aligned Actual (38):                 ts w ei m i ŋ ɕ iɛ n t ɤ ʂ ɨ t a pʰ wɔ l emp ɤ y oʊ i ʈʂ ɨ t ɤ tʰ iɛ n t i k wa n n iɛ del
# Aligned Predictions (37):            tɕ y n m i ŋ ɕ iɛ n t ɨ ʂ ɨ t a pʰ wɔ l ins oʊ y del i ʈʂ ɨ t ɨ tʰ iɛ n t ɨ k wa n n iɛ
#
# MDD metrics:                        ['FR', 'FR', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['WD', 'WD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 76.00%,  TR 0.00%,  FA 0.00%,  FR 24.00%,  CD 76.00%,  WD 24.00%
# MDD Error Types:                    ["sub(0:'ts' -> 'tɕ')", "sub(1:'w' -> 'y')", "sub(2:'ei' -> 'n')", 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', "sub(10:'ɤ' -> 'ɨ')", 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', "ins(18:'wɔ')", "sub(18:'ɤ' -> 'oʊ')", 'ok', "del(20:'oʊ')", 'ok', 'ok', 'ok', 'ok', "sub(25:'ɤ' -> 'ɨ')", 'ok', 'ok', 'ok', 'ok', "sub(30:'i' -> 'ɨ')", 'ok', 'ok', 'ok', 'ok', 'ok', "del(36:'n')"]
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: f
# Recognized as: f
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tsʰ
# Recognized as: ʈʂʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ai
# Recognized as: a
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Most Similar Pronunciation: ɤ
#
# Details:
#   - Missing Attributes: Velar, Voiced, Nasal
#   - Extra Attributes: Rounded, Unrounded, High-Mid, Close-Mid, Back
#   - Your Pronunciation Attributes: Unrounded, Rounded, Back, Close-Mid, High-Mid
#   - Expected Attributes: Voiced, Nasal, Velar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʂ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɨ
# Recognized as: ʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: i
# Recognized as: ɨ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Most Similar Pronunciation: i
#
# Details:
#   - Missing Attributes: Velar, Voiced, Nasal
#   - Extra Attributes: Rounded, Close, Unrounded, High, Front
#   - Your Pronunciation Attributes: Unrounded, Rounded, Front, Close, High
#   - Expected Attributes: Voiced, Nasal, Velar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: x
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: wa
# Recognized as: x
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Most Similar Pronunciation: ia
#
# Details:
#   - Missing Attributes: Alveolar, Voiced, Nasal
#   - Extra Attributes: midSound, Central, Low, diphthong, Open, neutral
#   - Your Pronunciation Attributes: Central, Open, Low, neutral, diphthong, midSound
#   - Expected Attributes: Voiced, Nasal, Alveolar
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tɕ
# Most Similar Pronunciation: n
#
# Details:
#   - Missing Attributes: alveolopalatal, Affricate, Unaspirated, Voiceless
#   - Extra Attributes: Alveolar, Voiced, Nasal, Rounded
#   - Your Pronunciation Attributes: Voiced, Nasal, Alveolar, Rounded
#   - Expected Attributes: Unaspirated, Voiceless, Affricate, alveolopalatal
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: i
# Recognized as: tɕ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Recognized as: i
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           f ɑ ŋ   tsʰ ai   n ɤ ŋ   ʂ ɨ   i ŋ   x wa n   tɕ i ŋ
# Actual:                             f ɑ ŋ tsʰ ai n ɤ ŋ ʂ ɨ i ŋ x wa n tɕ i ŋ
# Model Predictions:                  f ɑ ŋ ʈʂʰ a i n ɤ ŋ ʂ ɨ i n x ia n tɕ i
# MDD metrics:                        ['TA', 'TA', 'TA', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 17.00%,  TR 0.00%,  FA 0.00%,  FR 83.00%,  CD 17.00%,  WD 83.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'Substitution', 'Deletion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Deletion', 'Insertion', 'Substitution']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: n
# Recognized as: n
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: a
# Recognized as: a
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ioʊ
# Recognized as: ioʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʊ
# Recognized as: ʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: p
# Recognized as: p
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: ɑʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Most Similar Pronunciation: ei
#
# Details:
#   - Missing Attributes: None
#   - Extra Attributes: earlySound, diphthong
#   - Your Pronunciation Attributes: Unrounded, Back, Close-Mid, High-Mid, diphthong, earlySound
#   - Expected Attributes: Unrounded, Back, Close-Mid, High-Mid
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: y
# Recognized as: y
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: oʊ
# Recognized as: oʊ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɨ
# Recognized as: ɨ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʈʂ
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: u
# Recognized as: u
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ts
# Recognized as: ʈʂ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ai
# Recognized as: ai
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕ
# Recognized as: tɕ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: x
# Recognized as: x
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: wa
# Recognized as: wa
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: k
# Recognized as: k
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ei
# Recognized as: ei
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: t
# Recognized as: t
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: i
# Recognized as: i
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: l
# Recognized as: l
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɤ
# Recognized as: ɤ
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           n a   tɕ ioʊ   y ʊ ŋ   p u   ʈʂ ɤ   i   k ɤ   y oʊ   i   ʈʂ ɨ   t ɤ   ʈʂ u   ts ai   l ai   tɕ i   x wa   k w ei   t i ŋ   l ɤ
# Actual:                             n a tɕ ioʊ y ʊ ŋ p u ʈʂ ɤ i k ɤ y oʊ i ʈʂ ɨ t ɤ ʈʂ u ts ai l ai tɕ i x wa k w ei t i ŋ l ɤ
# Model Predictions:                  n a tɕ ioʊ y ʊ ŋ p u ʈʂ ɑʊ i k ei y oʊ i ʈʂ ɨ t ɤ ʈʂ u ʈʂ ai l ai tɕ i x wa k w ei t i ŋ l ɤ
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD']
# MDD metrics percentage:             TA 92.00%,  TR 0.00%,  FA 0.00%,  FR 8.00%,  CD 92.00%,  WD 8.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'Insertion', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok']
# ==================================================
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: kʰ
# Recognized as: kʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: w
# Recognized as: w
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ɑ
# Recognized as: ɑ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ŋ
# Recognized as: ŋ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: tɕʰ
# Recognized as: tɕʰ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: iɛ
# Recognized as: iɛ
#
# ✅ Correct Pronunciation!
# Phoneme/Tone: ʂ
# Recognized as: ʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: w
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tsʰ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: w
# Recognized as: ʈʂʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ə
# Recognized as: w
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: ə
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: t
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: t
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tɕ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: i
# Recognized as: tɕ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Recognized as: i
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʈʂ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: ʈʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ŋ
# Recognized as: ɤ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ʂ
# Recognized as: ŋ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɨ
# Recognized as: ʂ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: x
# Recognized as: ɨ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ə
# Recognized as: x
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: ə
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: tsʰ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: a
# Recognized as: ʈʂʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: n
# Recognized as: a
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: kʰ
# Recognized as: n
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: u
# Recognized as: kʰ
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: t
# Recognized as: u
#
# ❌ Wrong Pronunciation Detected!
# Phoneme/Tone: ɤ
# Recognized as: t
#
# ==================== SUMMARY: one-to-one ====================
# Supposed:                           kʰ w ɑ ŋ   tɕʰ iɛ   ʂ ɤ ŋ   tsʰ w ə n   t ɤ   tɕ i ŋ   ʈʂ ɤ ŋ   ʂ ɨ   x ə n   tsʰ a n   kʰ u   t ɤ
# Actual:                             kʰ w ɑ ŋ tɕʰ iɛ ʂ ɤ ŋ tsʰ w ə n t ɤ tɕ i ŋ ʈʂ ɤ ŋ ʂ ɨ x ə n tsʰ a n kʰ u t ɤ
# Model Predictions:                  kʰ w ɑ ŋ tɕʰ iɛ ʂ w ɤ ŋ ʈʂʰ w ə n t ɤ tɕ i n ʈʂ ɤ ŋ ʂ ɨ x ə n ʈʂʰ a n kʰ u t
# MDD metrics:                        ['TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'TA', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR', 'FR']
# Diagonsed result:                   ['CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'CD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD', 'WD']
# MDD metrics percentage:             TA 21.00%,  TR 0.00%,  FA 0.00%,  FR 79.00%,  CD 21.00%,  WD 79.00%
# MDD Error Types:                    ['ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'ok', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Deletion', 'Insertion', 'Substitution', 'Substitution']
# ==================================================

# %%
# Print the total calculations
num_sentences = i  
avg_TA = total_TA / num_sentences
avg_FA = total_FA / num_sentences
avg_TR = total_TR / num_sentences
avg_FR = total_FR / num_sentences
avg_CD = total_CD / num_sentences
avg_WD = total_WD / num_sentences

# Compute the rates
FAR = total_FA / (total_FA + total_TR) if (total_FA + total_TR) > 0 else 0
# a rate that accept wrong answer 

FRR = total_FR / (total_FR + total_TA) if (total_FR + total_TA) > 0 else 0
# a rate that reject correct answer

DER = total_WD / (total_CD + total_WD) if (total_CD + total_WD) > 0 else 0
# a rate that detect wrong answer

# Print results
print("="*30 + " PERFORMANCE METRICS " + "="*30)
print(f"False Acceptance Rate (FAR): {FAR:.4f}")
print(f"False Rejection Rate (FRR): {FRR:.4f}")
print(f"Diagnostic Error Rate (DER): {DER:.4f}")
print("="*80 + "\n")

## Final Confusion Amtrix
print("="*30 + " FINAL CONFUSION MATRIX " + "="*30)
print(f"Total Sentences Evaluated: {num_sentences}")
print(f"Total MDD Metrics:   TA {total_TA}, TR {total_TR}, FA {total_FA}, FR {total_FR}, CD {total_CD}, WD {total_WD}")
print(f"Average MDD %:       TA {avg_TA:.2f}%, TR {avg_TR:.2f}%, FA {avg_FA:.2f}%, FR {avg_FR:.2f}%, CD {avg_CD:.2f}%, WD {avg_WD:.2f}%")
print("="*80 + "\n")

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

total_TA = int(total_TA)
total_FA = int(total_FA)
total_TR = int(total_TR)
total_FR = int(total_FR)

conf_matrix = np.array([
    [total_TA, total_FA],  # TA (True Accept), FA (False Accept)
    [total_FR, total_TR]    # FR (False Reject), TR (True Reject)
])

labels = ["Accept", "Reject"]

plt.figure(figsize=(6, 5))
sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels)

plt.xlabel("Predicted Labels")
plt.ylabel("True Labels")
plt.title("Confusion Matrix - Phoneme Only Model")
plt.show()
# Out:
# ============================== PERFORMANCE METRICS ==============================
# False Acceptance Rate (FAR): 0.1429
# False Rejection Rate (FRR): 0.1957
# Diagnostic Error Rate (DER): 0.1952
# ================================================================================
#
# ============================== FINAL CONFUSION MATRIX ==============================
# Total Sentences Evaluated: 50
# Total MDD Metrics:   TA 3912, TR 114, FA 19, FR 952, CD 4024.0, WD 976.0
# Average MDD %:       TA 78.24%, TR 2.28%, FA 0.38%, FR 19.04%, CD 80.48%, WD 19.52%
# ================================================================================
